# %%
#conditional statement traffic code
light = input("light : ")
if(light=="red"):
    print("stop")
elif(light == "yellow"):
    print("wait")
elif(light == "green"):
    print("go")
else:
    print("light is broken")
# Out:
# light :  green
# go

# %%
 marks = int( input("marks = "))
if marks >= 90 :
    print("A")
elif marks >= 80 and marks <90 :
    print("B")
else:
    print ("C")
# Out:
# marks =  90
# A

# %%
#simple interest
p = float(input("p: "))
r = float(input("r: "))
t = float(input("t: "))
si= (p*r*t)/100
print(si)
# Out:
# p:  50000
# r:  5
# t:  3
# 7500.0

# %%
#type conversion
a,b = 1,2.0
sum= a+b
print(sum)
# Out:
# 3.0

# %%
#type cast
a,b = 1,"2"
c = int(b)
c= a+ c
print(c)
# Out:
# 3
