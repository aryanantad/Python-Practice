# %%
marks = [22.4,33.2,36,59]
print(marks)
print(type(marks))
print(len(marks))
# Out:
# [22.4, 33.2, 36, 59]
# <class 'list'>
# 4

# %%
#slicing
marks = [ 85,94,76,48,25]
print(marks[1:4])
print(marks[0:4])
# Out:
# [94, 76, 48]
# [85, 94, 76, 48]

# %%
#list methods
list =[2,1,3]
list.append(4)
print(list)
print(list.sort())
print(list.sort(reverse = True))
list.reverse()
print(list)
list.insert(2,6)
print(list)
list.pop(1)
print(list)
list.remove(1)
print(list)
# Out:
# [2, 1, 3, 4]
# None
# None
# [1, 2, 3, 4]
# [1, 2, 6, 3, 4]
# [1, 6, 3, 4]
# [6, 3, 4]

# %%
#tuple
tup= (1,65,3,5)
print(type(tup))
print(tup[0])
# Out:
# <class 'tuple'>
# 1

# %%
#slicing in tuple
tup =( 0,2,6)
print(tup[1:3])
# Out:
# (2, 6)

# %%
#list methods
tup =( 0,2,6)
tup.index(2)
print(tup)
tup.count(2)
print(tup)
# Out:
# (0, 2, 6)
# (0, 2, 6)

# %%
#WAP to ask user to enter name of 3 fav movies and store them in list
movies = []
mov1 = input("enter 1st movie:")
mov2 = input("enter 2st movie:")
mov3 = input("enter 3st movie:")
movies.append(mov1)
movies.append(mov2)
movies.append(mov3)
print(movies)
# Out:
# enter 1st movie: spiderman
# enter 2st movie: ironman
# enter 3st movie: loki
# ['spiderman', 'ironman', 'loki']

# %%
#WAP to check if list contains palindrome of elements (hint: use copy() method)
list1= [1,2,3]
list2 = [1,2,3]
copy_list1 = list1.copy()
copy_list1.reverse()

if(copy_list1 == list1):
    print("palindrome")
else: 
    print("not")
# Out:
# not
